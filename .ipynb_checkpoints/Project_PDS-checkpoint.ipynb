# %% [markdown]
# #### WARNING: This file takes approximately 5 minutes to run completely. The Web Scrapping takes 4 minutes and 30 seconds to run and there is a block of code that requires an input from the user.

# %% [markdown]
# # Group06
# - Simão Costa - 20241772
# - Leonardo Rodrigues - 20241411
# - Jaime Abreu - 20241823
# - Murshid Kazi - 20240642

# %%
import sys
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import time
import requests
import bs4
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import re
import folium

# %%
print(f"Python version: {sys.version}")
print(f"Pandas version: {pd.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")
print(f"Beautiful Soup version: {bs4.__version__}")
print(f"Selenium version: {selenium.__version__}")
print(f"Folium version: {folium.__version__}")
# Out:
# Python version: 3.13.7 | packaged by Anaconda, Inc. | (main, Sep  9 2025, 19:54:37) [MSC v.1929 64 bit (AMD64)]
# Pandas version: 2.3.3
# Matplotlib version: 3.10.6
# Seaborn version: 0.13.2
# Beautiful Soup version: 4.13.5
# Selenium version: 4.38.0
# Folium version: 0.20.0

# %% [markdown]
# ## Data Wrangling and Analysis

# %% [markdown]
# We are going to start our project importing our dataset. We skip the first row because it is empty and we separate every column by '|'.

# %%
data=pd.read_csv('city_data.csv',sep='|', skiprows=1)
data.head()
# Out:
#                 City  Population Density  Population  Working Age Population   \
# 0    Vienna, Austria               310.0     2983513                2018818.0
# 1  Salzburg, Austria               243.0      375489                 250472.0
# 2  Brussels, Belgium               681.0     3284548                2137425.0
# 3   Antwerp, Belgium               928.0     1139663                 723396.0
# 4      Gent, Belgium               552.0      645813                 417832.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 0                    20.1               10.2         55770.0
# 1                    20.3                3.0         66689.0
# 2                    27.5               10.7         62500.0
# 3                    27.7                6.2         57595.0
# 4                    24.8                NaN         53311.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 0                                3  German, English, Turkish, Serbian
# 1                                0                             German
# 2                                3     French, Dutch, Arabic, English
# 3                                3              Dutch, French, Arabic
# 4                                2                      Dutch, French
#
#    Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 0                    2500                 1050                    2061
# 1                    3200                 1100                    2186
# 2                    3350                 1200                    1900
# 3                    2609                  900                    1953
# 4                    2400                  827                    1200
#
#    Average Price Groceries     Last Data Update
# 0                    340.0  2024-06-15 00:00:00
# 1                      NaN  2023-11-03 00:00:00
# 2                      NaN  2023-04-22 00:00:00
# 3                      NaN  2024-08-09 00:00:00
# 4                    120.0  2023-07-17 00:00:00

# %% [markdown]
# After that, we analyse our data. We use **.info()** and **.describe()** to get our variable types and more details.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Avgerage Rent Price              86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Average Price Groceries          6 non-null      float64
#  13  Last Data Update                 86 non-null     object
# dtypes: float64(6), int64(5), object(3)
# memory usage: 9.5+ KB

# %%
data.describe(include='all').T
# Out:
#                                 count unique                  top freq  \
# City                               86     84      Berlin. Germany    2
# Population Density               85.0    NaN                  NaN  NaN
# Population                       86.0    NaN                  NaN  NaN
# Working Age Population           85.0    NaN                  NaN  NaN
# Youth Dependency Ratio           86.0    NaN                  NaN  NaN
# Unemployment Rate                85.0    NaN                  NaN  NaN
# GDP per Capita                   85.0    NaN                  NaN  NaN
# Days of very strong heat stress  86.0    NaN                  NaN  NaN
# Main Spoken Languages              85     54              Italian    6
# Average Monthly Salary           86.0    NaN                  NaN  NaN
# Avgerage Rent Price              86.0    NaN                  NaN  NaN
# Average Cost of Living           86.0    NaN                  NaN  NaN
# Average Price Groceries           6.0    NaN                  NaN  NaN
# Last Data Update                   86     84  2023-06-29 00:00:00    2
#
#                                            mean             std       min  \
# City                                        NaN             NaN       NaN
# Population Density                  1115.141176     2542.778533      65.0
# Population                            1754370.5   1843133.29993   73895.0
# Working Age Population           1158293.623529  1232533.810675   46359.0
# Youth Dependency Ratio                 24.09686        3.266421      19.3
# Unemployment Rate                      6.667059        4.553632       1.4
# GDP per Capita                     51750.269647    21495.617843  10089.92
# Days of very strong heat stress        4.348837       10.038476       0.0
# Main Spoken Languages                       NaN             NaN       NaN
# Average Monthly Salary              2434.488372     1188.602984     750.0
# Avgerage Rent Price                 1070.104651      498.964576     100.0
# Average Cost of Living              1808.383721       727.99968     800.0
# Average Price Groceries              225.833333       97.890585     100.0
# Last Data Update                            NaN             NaN       NaN
#
#                                       25%        50%        75%         max
# City                                  NaN        NaN        NaN         NaN
# Population Density                  304.0      548.0     1020.0     20983.0
# Population                       528118.5  1178397.0  2315896.0  12396541.0
# Working Age Population           358020.0   733794.0  1534225.0   8274794.0
# Youth Dependency Ratio             21.425      23.15     25.925        37.8
# Unemployment Rate                     3.7        5.3        8.1        23.0
# GDP per Capita                    38664.0    49329.0    63083.0    146094.0
# Days of very strong heat stress       0.0        1.0        3.0        59.0
# Main Spoken Languages                 NaN        NaN        NaN         NaN
# Average Monthly Salary             1412.5     2400.0     3200.0      6636.0
# Avgerage Rent Price                 800.0     1050.0     1250.0      3190.0
# Average Cost of Living             1300.0     1665.0     2100.0      4862.0
# Average Price Groceries             147.5      243.0     295.75       340.0
# Last Data Update                      NaN        NaN        NaN         NaN

# %% [markdown]
# Now, we start making corrections of our data.
# First we fix typos that we have in the dataset. The first typo is *'Avgerage'*, the second is the empty space at the end of the variable *'Working Age Population'*.
# Lastly, we convert the variable *'Last Data Update'* to datetime in order to be possible to work with that later.

# %%
data.rename(columns={'Avgerage Rent Price':'Average Rent Price'}, inplace=True)   #fixing typos
data.rename(columns={'Working Age Population ':'Working Age Population'}, inplace=True)

# %%
data['Last Data Update'] = pd.to_datetime(data['Last Data Update'], errors='coerce')   #convert to datetime
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Average Rent Price               86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Average Price Groceries          6 non-null      float64
#  13  Last Data Update                 86 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(5), object(2)
# memory usage: 9.5+ KB

# %% [markdown]
# Now, we checked if we have any duplicates in the data. Since we have, we wrote a block of code to show us the duplicates.

# %%
dupes = data.duplicated(subset=['City'])    #checking if we have duplicates
print("Duplicates found:", dupes.sum())
# Out:
# Duplicates found: 2

# %%
data[data.duplicated(subset=['City'], keep=False)].sort_values('City')   #showing the duplicates
# Out:
#                City  Population Density  Population  Working Age Population  \
# 15  Berlin. Germany               304.0     5303922               3481212.0
# 16  Berlin. Germany               304.0     5303922               3481212.0
# 32    Malaga, Spain               571.0      869096                585608.0
# 33    Malaga, Spain               571.0      869096                585608.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 15                    21.3                4.7         46548.0
# 16                    21.3                4.7         46548.0
# 32                    23.5               17.7         27694.0
# 33                    23.5               17.7         27694.0
#
#     Days of very strong heat stress             Main Spoken Languages  \
# 15                                3  German, Turkish, Arabic, English
# 16                                3  German, Turkish, Arabic, English
# 32                                0                  Spanish, English
# 33                                0                  Spanish, English
#
#     Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 15                    3200                1220                    2200
# 16                    3200                1220                    2200
# 32                    2200                1312                    1400
# 33                    2200                1312                    1400
#
#     Average Price Groceries Last Data Update
# 15                      NaN       2023-06-29
# 16                      NaN       2023-06-29
# 32                      NaN       2023-11-27
# 33                      NaN       2023-11-27

# %% [markdown]
# After we checked the duplicates, we deleted them and we made sure that we had no more.

# %%
data = data.sort_values('Last Data Update').drop_duplicates(subset=['City'], keep='last')  #deleting the duplicates
print("Duplicates found:", data.duplicated(subset=['City']).sum())                         #making sure we don't have any more duplicates
# Out:
# Duplicates found: 0

# %% [markdown]
# Next, we looked at the missing values. We have some missing values to work on.

# %%
data.isna().sum().sort_values(ascending=False)  #checking missing values
# Out:
# Average Price Groceries            78
# Population Density                  1
# Working Age Population              1
# Unemployment Rate                   1
# GDP per Capita                      1
# Main Spoken Languages               1
# City                                0
# Population                          0
# Youth Dependency Ratio              0
# Days of very strong heat stress     0
# Average Monthly Salary              0
# Average Rent Price                  0
# Average Cost of Living              0
# Last Data Update                    0
# dtype: int64

# %% [markdown]
# First, we dropped the column *'Average Price Groceries'*. It does not make sense to keep it in the dataset. After that, we filled the missing values of the columns *'Population Density'*, *'Working Age Population'*, *'Unemployment Rate'*, *'GDP per Capita'* with the median of the respective columns.

# %%
data.drop(columns=['Average Price Groceries'], inplace=True)  #dropping 'Average Price Groceries'

# %%
num_cols = ['Population Density', 'Working Age Population', 'Unemployment Rate', 'GDP per Capita']
for col in num_cols:                                          #filling in the missing values with the median value
    if col in data.columns:
        data[col] = data[col].fillna(data[col].median())

# %% [markdown]
# After all this is done, we noticed that the Country and City of each row were in the same column. To make it easier for future analysis, we split both using the **.split()** method by *', '*. Doing this, our new column *'Country'* goes to the end of the dataset on the right. For easier reading, we brought it next to *'City'* in the beggining on the left.

# %%
data[['City','Country']]=data['City'].str.split(', ', n=1, expand=True)

# %%
#putting the column 'Country' after 'City'
cols=data.columns.tolist()
cols.remove('Country')
cols.insert(cols.index('City')+1, 'Country')
data=data[cols]
data.head()
# Out:
#                  City      Country  Population Density  Population  \
# 10              Basel  Switzerland               793.0      550152
# 20  Frankfurt am Main      Germany               631.0     2710501
# 82         Gothenburg       Sweden               245.0     1037675
# 18             Munich      Germany               529.0     2907752
# 59             Venice        Italy               852.0      557748
#
#     Working Age Population  Youth Dependency Ratio  Unemployment Rate  \
# 10                358020.0                    21.5                5.3
# 20               1791435.0                    22.0                3.2
# 82                672152.0                    28.2                6.3
# 18               1955041.0                    21.1                2.1
# 59                347781.0                    19.3                6.1
#
#     GDP per Capita  Days of very strong heat stress    Main Spoken Languages  \
# 10         94826.0                                5  German, English, French
# 20         69372.0                                6          German, English
# 82         49588.0                                0         Swedish, English
# 18         83965.0                                1          German, English
# 59         39681.0                                6                  Italian
#
#     Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 10                    6366                2500                    4239
# 20                    3800                1300                    2350
# 82                    2500                1200                    2100
# 18                    3540                1500                    2550
# 59                    1400                1150                    1500
#
#    Last Data Update
# 10       2023-01-19
# 20       2023-02-04
# 82       2023-03-10
# 18       2023-03-16
# 59       2023-03-23

# %% [markdown]
# With all that done, we looked for any errors that might have occured during the previous phase. As expected we have some problems that need to be fixed.

# %%
problem_rows = data[data['Country'].isna()][['City']]
problem_rows
# Out:
#                City
# 16  Berlin. Germany
# 12   Lemesos;Cyprus

# %% [markdown]
# For this errors, we just applied the same method as previously described. We used **.split()** on those 2 rows but this time we split by *';'* and *'.'*.

# %%
data[['City','Country2']]=data['City'].str.split(';', n=1, expand=True)
data[['City','Country3']]=data['City'].str.split('.', n=1, expand=True)

# %% [markdown]
# With that done, we put every Country name in the same column, *'Country'*, and we dropped all the unnecessary columns.

# %%
data[['Country', 'Country2', 'Country3']] = data[['Country', 'Country2', 'Country3']].fillna('')
data['Country'] = data[['Country', 'Country2', 'Country3']].apply(lambda x: ', '.join(x[x != '']), axis=1)
data.drop(['Country2', 'Country3'], axis=1, inplace=True)
data.head()
# Out:
#                  City      Country  Population Density  Population  \
# 10              Basel  Switzerland               793.0      550152
# 20  Frankfurt am Main      Germany               631.0     2710501
# 82         Gothenburg       Sweden               245.0     1037675
# 18             Munich      Germany               529.0     2907752
# 59             Venice        Italy               852.0      557748
#
#     Working Age Population  Youth Dependency Ratio  Unemployment Rate  \
# 10                358020.0                    21.5                5.3
# 20               1791435.0                    22.0                3.2
# 82                672152.0                    28.2                6.3
# 18               1955041.0                    21.1                2.1
# 59                347781.0                    19.3                6.1
#
#     GDP per Capita  Days of very strong heat stress    Main Spoken Languages  \
# 10         94826.0                                5  German, English, French
# 20         69372.0                                6          German, English
# 82         49588.0                                0         Swedish, English
# 18         83965.0                                1          German, English
# 59         39681.0                                6                  Italian
#
#     Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 10                    6366                2500                    4239
# 20                    3800                1300                    2350
# 82                    2500                1200                    2100
# 18                    3540                1500                    2550
# 59                    1400                1150                    1500
#
#    Last Data Update
# 10       2023-01-19
# 20       2023-02-04
# 82       2023-03-10
# 18       2023-03-16
# 59       2023-03-23

# %% [markdown]
# After this, we made sure we had no more errors.

# %%
problem_rows = data[data['Country'].isna()][['City']]  #checking to see if there is any more problems
problem_rows
# Out:
# Empty DataFrame
# Columns: [City]
# Index: []

# %% [markdown]
# Looking at the data, we noticed that the rows were all mixed together. It is easier to look at them in an alphabetical order.

# %%
data = data.sort_values(by='Country').reset_index(drop=True)    #ordering the data in alphabetical order
data.index+=1
data.head()
# Out:
#        City   Country  Population Density  Population  Working Age Population  \
# 1      Lyon    France             10909.0      520774                365824.0
# 2    Berlin   Germany               304.0     5303922               3481212.0
# 3    Greece    Athens              1829.0     3530371               2287174.0
# 4    Vienna   Austria               310.0     2983513               2018818.0
# 5  Salzburg   Austria               243.0      375489                250472.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 1                   27.31                6.9         46226.0
# 2                   21.30                4.7         46548.0
# 3                   22.00               17.2         38580.0
# 4                   20.10               10.2         55770.0
# 5                   20.30                3.0         66689.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 1                               11                             French
# 2                                3   German, Turkish, Arabic, English
# 3                               17                     Greek, English
# 4                                3  German, English, Turkish, Serbian
# 5                                0                             German
#
#    Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 1                    2300                1200                    1800
# 2                    3200                1220                    2200
# 3                    1050                 600                    1200
# 4                    2500                1050                    2061
# 5                    3200                1100                    2186
#
#   Last Data Update
# 1       2023-03-31
# 2       2023-06-29
# 3       2024-07-16
# 4       2024-06-15
# 5       2023-11-03

# %% [markdown]
# While ordering the dataset, we noticed that there were some Countries that should not be at the top. To correct this, we use the **.strip()** method to remove the space at the end of the Country name.

# %%
data['Country'] = data['Country'].str.strip()
data = data.sort_values(by='Country').reset_index(drop=True)
data.index+=1
data.head()
# Out:
#        City  Country  Population Density  Population  Working Age Population  \
# 1    Greece   Athens              1829.0     3530371               2287174.0
# 2    Vienna  Austria               310.0     2983513               2018818.0
# 3  Salzburg  Austria               243.0      375489                250472.0
# 4  Brussels  Belgium               681.0     3284548               2137425.0
# 5   Antwerp  Belgium               928.0     1139663                723396.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 1                    22.0               17.2         38580.0
# 2                    20.1               10.2         55770.0
# 3                    20.3                3.0         66689.0
# 4                    27.5               10.7         62500.0
# 5                    27.7                6.2         57595.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 1                               17                     Greek, English
# 2                                3  German, English, Turkish, Serbian
# 3                                0                             German
# 4                                3     French, Dutch, Arabic, English
# 5                                3              Dutch, French, Arabic
#
#    Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 1                    1050                 600                    1200
# 2                    2500                1050                    2061
# 3                    3200                1100                    2186
# 4                    3350                1200                    1900
# 5                    2609                 900                    1953
#
#   Last Data Update
# 1       2024-07-16
# 2       2024-06-15
# 3       2023-11-03
# 4       2023-04-22
# 5       2024-08-09

# %% [markdown]
# After doing this, we noticed one more error. In the first row, the City and Country names are swapped. We need to fix this.

# %%
row=1
data.at[row, 'City'], data.at[row, 'Country'] = data.at[row, 'Country'], data.at[row, 'City']

# %% [markdown]
# Now, we order it again by *'Country'* and *'City'*.

# %%
data = data.sort_values(by=['Country','City']).reset_index(drop=True)    #ordering the data in alphabetical order (Country and City)
data.index+=1
data.head()
# Out:
#        City  Country  Population Density  Population  Working Age Population  \
# 1  Salzburg  Austria               243.0      375489                250472.0
# 2    Vienna  Austria               310.0     2983513               2018818.0
# 3   Antwerp  Belgium               928.0     1139663                723396.0
# 4    Bruges  Belgium               840.0      119765                 74600.0
# 5  Brussels  Belgium               681.0     3284548               2137425.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 1                   20.30                3.0         66689.0
# 2                   20.10               10.2         55770.0
# 3                   27.70                6.2         57595.0
# 4                   25.63                5.6         63083.0
# 5                   27.50               10.7         62500.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 1                                0                             German
# 2                                3  German, English, Turkish, Serbian
# 3                                3              Dutch, French, Arabic
# 4                                0                      Dutch, French
# 5                                3     French, Dutch, Arabic, English
#
#    Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 1                    3200                1100                    2186
# 2                    2500                1050                    2061
# 3                    2609                 900                    1953
# 4                    2700                1250                    1708
# 5                    3350                1200                    1900
#
#   Last Data Update
# 1       2023-11-03
# 2       2024-06-15
# 3       2024-08-09
# 4       2023-10-25
# 5       2023-04-22

# %% [markdown]
# Now, we want to make sure one last time that our data is pre-processed and that we don't have missing values. Unfornately, there is still one missing value.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 1 to 84
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             84 non-null     object
#  1   Country                          84 non-null     object
#  2   Population Density               84 non-null     float64
#  3   Population                       84 non-null     int64
#  4   Working Age Population           84 non-null     float64
#  5   Youth Dependency Ratio           84 non-null     float64
#  6   Unemployment Rate                84 non-null     float64
#  7   GDP per Capita                   84 non-null     float64
#  8   Days of very strong heat stress  84 non-null     int64
#  9   Main Spoken Languages            83 non-null     object
#  10  Average Monthly Salary           84 non-null     int64
#  11  Average Rent Price               84 non-null     int64
#  12  Average Cost of Living           84 non-null     int64
#  13  Last Data Update                 84 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(5), object(3)
# memory usage: 9.3+ KB

# %% [markdown]
# Since it is on a categorical column, we created a specific label for it called '*Unknown'*. We checked again for any problems and we  have everything in place.

# %%
object_col = data.select_dtypes(include='object').columns
data[object_col] = data[object_col].fillna("Unknown")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 1 to 84
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             84 non-null     object
#  1   Country                          84 non-null     object
#  2   Population Density               84 non-null     float64
#  3   Population                       84 non-null     int64
#  4   Working Age Population           84 non-null     float64
#  5   Youth Dependency Ratio           84 non-null     float64
#  6   Unemployment Rate                84 non-null     float64
#  7   GDP per Capita                   84 non-null     float64
#  8   Days of very strong heat stress  84 non-null     int64
#  9   Main Spoken Languages            84 non-null     object
#  10  Average Monthly Salary           84 non-null     int64
#  11  Average Rent Price               84 non-null     int64
#  12  Average Cost of Living           84 non-null     int64
#  13  Last Data Update                 84 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(5), object(3)
# memory usage: 9.3+ KB

# %% [markdown]
# With the data finally pre-processed, we are ready to answer the questions now.

# %% [markdown]
# ### Question 1 - How did you handle missing values and duplicate records in the dataset? Justify your approach.

# %% [markdown]
# To take care of the missing values, we substitute them with the median for the numerical values because it represents better the skewness than the mean. For the categorical values we imputed a dedicated label called "Unknown" to preserve the information from the missing values. In the case of the column 'Average Price Groceries', we just deleted it from our dataset because it is not valuable since we only had 6 values.
#
# The duplicated values were identified and removed since they don't have any additional information.

# %% [markdown]
# ### Question 2

# %% [markdown]
# ### a) Which country appears most frequently in the dataset? How many cities are associated with it?

# %%
country_counts = data['Country'].value_counts()  # counting how many times each country appears in the dataset
top_country = country_counts.idxmax()            # getting the most frequent country
num_cities = country_counts.max()                # getting the numbers of cities that country has in the dataset
print(f"Country with most cities: {top_country}, with {num_cities} cities")
# Out:
# Country with most cities: Germany, with 10 cities

# %% [markdown]
# ### b) How many cities are present in total? How many are associated with Greece?

# %%
print(f"We have {data['City'].nunique()} cities, which {data[data['Country']=='Greece']['City'].nunique()} are in Greece")
# Out:
# We have 84 cities, which 2 are in Greece

# %% [markdown]
# ### c) Which is the least spoken language in the dataset? Which are the top 3 most spoken languages?

# %% [markdown]
# For this question, we considered the least spoken languages the ones that are talked in the least number of cities.

# %%
data['Main Spoken Languages']= data['Main Spoken Languages'].str.replace(';', ',')                         # replaces every semicolon to comma 
data_exploded = data.assign(Languages=data['Main Spoken Languages'].str.split(',')).explode('Languages')   # creates a temporary column (Languages), gets all languages in a different row
data_exploded['Languages'] = data_exploded['Languages'].str.strip()                                        # removing the blank spaces
language_counts = data_exploded['Languages'].value_counts()                                                # counting the values
language_counts= language_counts.drop('Unknown', errors= 'ignore')                                         # removing the 'Unknown' category
least_spoken = []
for language, count in language_counts.items():
    if count==1:
        least_spoken.append(language)

# %%
top_3 = language_counts.head(3)              # getting the top 3 most spoken languages
languages_t3 = ', '.join(top_3.index)+ '.'   # join the index (language names) with commas
print(f'The 3 most spoken languages are: {languages_t3}')
# Out:
# The 3 most spoken languages are: English, German, Turkish.

# %%
languages_l=', '.join(least_spoken)+ '.'
print("The least spoken languages are", languages_l)
# Out:
# The least spoken languages are Serbian, Scots, Scots Gaelic, Valencian, Catalan, Romanian, Slovene, Slovak, Maltese, Luxembourgish, Latvian, Estonian, Bengali.

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### a) Entries uploaded before April 2023 need to be updated. Which cities would require an update?

# %%
to_upload = data[data['Last Data Update'] < "2023-04-01"]     # gets all rows before the specific date
update=', '.join(to_upload['City'])+ '.'                      # joins all the cities in a string format
print(f'These cities require an update: {update}')
# Out:
# These cities require an update: Lyon, Frankfurt am Main, Munich, Venice, Gothenburg, Basel.

# %% [markdown]
# ### b) How many days ago was the last update? On what day, month, and year did it occur?

# %%
last_update = data['Last Data Update'].max()            #gets the date of the last update 
print(f'The last update was in {last_update.day} {last_update.strftime("%B")} {last_update.year}.')
# Out:
# The last update was in 12 December 2024.

# %% [markdown]
# ### Question 4

# %% [markdown]
# ### a) How are the Unemployment Rate and GDP per Capita distributed and related? What does this relationship suggest? Provide a visual representation.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,6))

axes[0].hist(data['Unemployment Rate'], bins=20, color='green')
axes[0].set_title('Distribution of Unemployment Rate')
axes[0].set_xlabel('Unemployment Rate (%)')
axes[0].set_ylabel('Frequency')

axes[1].scatter(data['Unemployment Rate'], data['GDP per Capita'], color='green')
axes[1].set_title('Unemployment vs GDP per Capita')
axes[1].set_xlabel('Unemployment Rate (%)')
axes[1].set_ylabel('GDP per Capita (USD)')

plt.show()

# %%
corr = data['Unemployment Rate'].corr(data['GDP per Capita'])
print("The correlation has a value of", corr)
# Out:
# The correlation has a value of -0.3392607671353986

# %% [markdown]
# The histogram reveals a right-skewed distribution for unemployment, with most observations concentrated at the lower end. The scatter plot indicates a negative relationship where higher GDP per Capita is typically associated with lower unemployment rates.

# %% [markdown]
# The correlation coefficient of -0.339 quantifies the relationship shown in the scatter plot as a weak negative correlation. This suggests that while higher unemployment is statistically associated with lower economic output per person, unemployment is not a primary predictor of GDP. The weak correlation suggests that the economic wealth is influenced by a lot of different factors, not just the employment rate.

# %% [markdown]
# ### b) Which are the top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living? What about the top 5 countries with the smallest average difference? Show these results with meaningful visualizations.

# %%
data['Difference'] = data['Average Monthly Salary'] - data['Average Cost of Living']
top10_cities = data.nlargest(10, 'Difference')[['City','Difference']]               # gets the 10 with the largest difference and only shows the colummns City and Difference
country_diff = data.groupby('Country')['Difference'].mean().sort_values()           # groups all cities by country, calculates the mean and sorts the values 
top10_countries = country_diff.head(10)

# %%
# Create figure with 2 graphics
fig, axes = plt.subplots(1, 2, figsize=(15,5))                                      # width=15, height=5

#left barchart
colors = ['green']*5 + ['grey']*5
axes[0].barh(top10_cities['City'], top10_cities['Difference'], color=colors)
axes[0].invert_yaxis()
axes[0].set_title('Top 5 Cities With the Largest Difference')
axes[0].set_xlabel('Difference')
axes[0].set_ylabel('City')

#right barchart
colors=['red']*5 + ['grey']*5
axes[1].barh(top10_countries.index, top10_countries.values, color=colors)
axes[1].invert_yaxis()
axes[1].set_title('Top 5 Countries with Smallest Average Difference')
axes[1].set_xlabel('Difference')
axes[1].set_ylabel('Country')

plt.tight_layout()
plt.show()

# %% [markdown]
# Acoording to our data, the cities with the largest difference between average monthly salary and average cost of living are Basel, Tampere, Helsinki, Zurich and Geneva. In contradiction, the countries with the worst difference are Portugal, Greece, Slovak Republic, Turkiye and Poland.

# %% [markdown]
# ### c) Which is the best city for someone seeking:
# - #### an average monthly salary above €2000,
# - #### a cost of living below or equal to €1600, and
# - #### the lowest unemployment rate possible?

# %%
filtered = data[(data['Average Monthly Salary'] > 2000) & (data['Average Cost of Living'] <= 1600)]
best = filtered.sort_values('Unemployment Rate').head(1)
if filtered.empty:
    print("No city meets all criteria")
print(f'The best city for this specific criteria is {best['City'].values[0]}.')
# Out:
# The best city for this specific criteria is Dresden.

# %% [markdown]
# ### Question 5 - What are three additional insights you find meaningful when comparing the given cities?

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(
    data=data,
    x="Population Density",
    y="Average Monthly Salary",
    alpha=0.7
)
plt.xscale("log")
plt.xlabel("Population Density (log scale)")
plt.ylabel("Average Monthly Salary (€)")
plt.title("Population Density vs Average Monthly Salary")
plt.tight_layout()
plt.show()

# %% [markdown]
# The relationship between population density and average salary is weak, suggesting that higher population density alone does not guarantee higher wages. While some dense metropolitan areas offer higher salaries, many medium-density cities don't provide very good income levels.

# %%
data["Salary_to_Cost_Ratio"] = (data["Average Monthly Salary"] / data["Average Cost of Living"])

plt.figure(figsize=(10,5))
sns.histplot(data["Salary_to_Cost_Ratio"], kde=True, bins=15)
plt.axvline(1, linestyle="--", color="black")
plt.title("Distribution of Salary-to-Cost Ratio")
plt.xlabel("Salary / Cost of Living")
plt.ylabel("Number of Cities")
plt.tight_layout()
plt.show()

# %% [markdown]
# The salary-to-cost ratio reveals substantial differences in affordability across cities. Looking at this histogram, we can see that most cities offer an affordable life for the residents. Although this is true for most cities, there are some that the salary-to-cost ratio is smaller than 1 meaning that their residents' salary is not enough to cover their expenses.

# %%
plt.figure(figsize=(8,5))
sns.regplot(
    data=data,
    x="GDP per Capita",
    y="Unemployment Rate",
    scatter_kws={"alpha": 0.7}
)
plt.xlabel("GDP per Capita (USD)")
plt.ylabel("Unemployment Rate (%)")
plt.title("GDP per Capita vs Unemployment Rate")
plt.tight_layout()
plt.show()

# %% [markdown]
# Cities with higher GDP per capita generally exhibit lower unemployment rates, indicating that stronger economic output is associated with healthier labor markets. However, the dispersion of points suggests that GDP alone does not fully explain employment outcomes.

# %% [markdown]
# ## Building an Interactive Map

# %% [markdown]
# In this part, our goal is to create an interactive map of **Europe**. For that we need the coordinates of every city in our dataset. We can get the coordinates using **Web Scraping**.

# %% [markdown]
# ### Web Scrapping

# %% [markdown]
# Firstly, we create two columns in the dataset. One for latitude and another for longitude.

# %%
data["Latitude"] = None
data["Longitude"] = None

# %% [markdown]
# With this, we can start creating the functions for the web scrapping. When testing different types of code, we found that the most efficient and faster way is to search on Wikipedia the name of the city we want. That way the city's page gets loaded instantly, not needind to click any link. Our function *get_coordinates* does exactly that. It looks for the search bar and types the city's name.

# %%
def get_coordinates(browser, city):

    # Click search icon
    search_icon = browser.find_element(By.CLASS_NAME, "mw-ui-icon-search")
    search_icon.click()
    time.sleep(1)

    # Type city
    search_bar = browser.find_element(By.CLASS_NAME, "cdx-text-input__input")
    search_bar.clear()
    search_bar.send_keys(f"{city}")
    search_bar.send_keys(Keys.RETURN)
    time.sleep(1)


    soup = BeautifulSoup(browser.page_source, "html.parser")

    lat = soup.find("span", class_="latitude")
    lon = soup.find("span", class_="longitude")

    if lat and lon:
        return lat.text, lon.text

    time.sleep(1)

    return None

# %% [markdown]
# When testing we also found out that some cities didn't get instantly loaded on Wikipedia. With this in mind, we created another function. The function works similar to the previous one. It looks for the search bar but this one types the city name and country as well as the word 'city' in the end. With this, we guarantee that we city's page is the first one to appear. Our function clicks on the first link and gets on the city's page.

# %%
def get_coordinates_hard(browser, city, country):
        # Find search icon on browser and click it
        search_icon_input = browser.find_element(By.CLASS_NAME, "mw-ui-icon-search")
        search_icon_input.click()
        time.sleep(1)
        
        # Find search bar on browser, insert city and click enter
        search_bar_input = browser.find_element(By.CLASS_NAME, "cdx-text-input__input")
        search_bar_input.send_keys(f"{city}, {country} city")
        search_bar_input.send_keys(Keys.RETURN)
        time.sleep(1)
        
        html = browser.page_source
        readable_html = BeautifulSoup(html, "html.parser")
    
        latitude = readable_html.find("span", {"class": "latitude"})
        longitude = readable_html.find("span", {"class": "longitude"})
        
        links = browser.find_elements(By.CSS_SELECTOR, ".mw-search-result-heading a")

        links[0].click()
        time.sleep(1)

        soup = BeautifulSoup(browser.page_source, "html.parser")
        latitude = soup.find("span", class_="latitude")
        longitude = soup.find("span", class_="longitude")

        if latitude and longitude:
            return latitude.text, longitude.text

# %% [markdown]
# Since we have our functions prepared for the Wikipedia navigating, we just need one more function to open the browser on Wikipedia and to provide the city and country's name for the web scrapping. During our testing, we found that the cities that would require the addictional function were 'Gent', 'Split', 'Cork' and 'Luxembourg'. With that in mind, we just created a list with those cities and wrote the code so all cities would have coordinates.

# %%
def get_coordinates_insert(data):
    
    error_cities=['Gent', 'Split', 'Cork', 'Luxembourg']
    
    # Open browser at Wikipedia MAIN PAGE
    browser = webdriver.Chrome()
    browser.get("https://en.wikipedia.org/wiki/Main_Page")
    time.sleep(1)

    for idx in data.index:

        city = data.loc[idx, "City"]
        country = data.loc[idx, "Country"]

        print(f"Scraping the coordinates of: {city}, {country}")

        if city in error_cities:
            result=get_coordinates_hard(browser, city, country)
        else:
            result = get_coordinates(browser, city)

        if result:
            lat, lon = result
        else:
            lat, lon = None, None

        data.loc[idx, "Latitude"] = lat
        data.loc[idx, "Longitude"] = lon

    browser.quit()

# %%
get_coordinates_insert(data)
# Out:
# Scraping the coordinates of: Salzburg, Austria
# Scraping the coordinates of: Vienna, Austria
# Scraping the coordinates of: Antwerp, Belgium
# Scraping the coordinates of: Bruges, Belgium
# Scraping the coordinates of: Brussels, Belgium
# Scraping the coordinates of: Gent, Belgium
# Scraping the coordinates of: Dobrich, Bulgaria
# Scraping the coordinates of: Sofia, Bulgaria
# Scraping the coordinates of: Split, Croatia
# Scraping the coordinates of: Zagreb, Croatia
# Scraping the coordinates of: Lefkosia, Cyprus
# Scraping the coordinates of: Lemesos, Cyprus
# Scraping the coordinates of: Ostrava, Czechia
# Scraping the coordinates of: Prague, Czechia
# Scraping the coordinates of: Copenhagen, Denmark
# Scraping the coordinates of: Odense, Denmark
# Scraping the coordinates of: Tallinn, Estonia
# Scraping the coordinates of: Helsinki, Finland
# Scraping the coordinates of: Tampere, Finland
# Scraping the coordinates of: Lyon, France
# Scraping the coordinates of: Paris, France
# Scraping the coordinates of: Toulouse, France
# Scraping the coordinates of: Berlin, Germany
# Scraping the coordinates of: Cologne, Germany
# Scraping the coordinates of: Dresden, Germany
# Scraping the coordinates of: Dusseldorf, Germany
# Scraping the coordinates of: Frankfurt am Main, Germany
# Scraping the coordinates of: Hamburg, Germany
# Scraping the coordinates of: Hanover, Germany
# Scraping the coordinates of: Leipzig, Germany
# Scraping the coordinates of: Munich, Germany
# Scraping the coordinates of: Stuttgart, Germany
# Scraping the coordinates of: Athens, Greece
# Scraping the coordinates of: Thessaloniki, Greece
# Scraping the coordinates of: Budapest, Hungary
# Scraping the coordinates of: Debrecen, Hungary
# Scraping the coordinates of: Miskolc, Hungary
# Scraping the coordinates of: Cork, Ireland
# Scraping the coordinates of: Dublin, Ireland
# Scraping the coordinates of: Florence, Italy
# Scraping the coordinates of: Milan, Italy
# Scraping the coordinates of: Naples, Italy
# Scraping the coordinates of: Rome, Italy
# Scraping the coordinates of: Turin, Italy
# Scraping the coordinates of: Venice, Italy
# Scraping the coordinates of: Riga, Latvia
# Scraping the coordinates of: Luxembourg, Luxembourg
# Scraping the coordinates of: Malta, Malta
# Scraping the coordinates of: Amsterdam, Netherlands
# Scraping the coordinates of: Eindhoven, Netherlands
# Scraping the coordinates of: Rotterdam, Netherlands
# Scraping the coordinates of: The Hague, Netherlands
# Scraping the coordinates of: Utrecht, Netherlands
# Scraping the coordinates of: Bergen, Norway
# Scraping the coordinates of: Oslo, Norway
# Scraping the coordinates of: Stavanger, Norway
# Scraping the coordinates of: Cracow, Poland
# Scraping the coordinates of: Lodz, Poland
# Scraping the coordinates of: Warsaw, Poland
# Scraping the coordinates of: Braga, Portugal
# Scraping the coordinates of: Coimbra, Portugal
# Scraping the coordinates of: Lisbon, Portugal
# Scraping the coordinates of: Porto, Portugal
# Scraping the coordinates of: Giroc, Romania
# Scraping the coordinates of: Bratislava, Slovak Republic
# Scraping the coordinates of: Ljubljana, Slovenia
# Scraping the coordinates of: Barcelona, Spain
# Scraping the coordinates of: Madrid, Spain
# Scraping the coordinates of: Malaga, Spain
# Scraping the coordinates of: Seville, Spain
# Scraping the coordinates of: Valencia, Spain
# Scraping the coordinates of: Gothenburg, Sweden
# Scraping the coordinates of: Malmo, Sweden
# Scraping the coordinates of: Stockholm, Sweden
# Scraping the coordinates of: Basel, Switzerland
# Scraping the coordinates of: Geneva, Switzerland
# Scraping the coordinates of: Zurich, Switzerland
# Scraping the coordinates of: Adana, Turkiye
# Scraping the coordinates of: Ankara, Turkiye
# Scraping the coordinates of: Edinburgh, United Kingdom
# Scraping the coordinates of: Glasgow, United Kingdom
# Scraping the coordinates of: Leeds, United Kingdom
# Scraping the coordinates of: Liverpool, United Kingdom
# Scraping the coordinates of: London, United Kingdom

# %% [markdown]
# The web scrapping part is now complete. If we look at the dataset, we notice that the coordinates are not in decimal degrees. To be able to create a map, we need to have the coordinates in the correct format. For this purpose, we created a function to correct this.

# %%
def dms_to_decimal(dms):
    """
    Converts various DMS formats to decimal degrees.
    Examples it supports:
    - 40°25′08″N
    - 40°25′N
    - 40.4168°N
    """

    if pd.isna(dms):
        return None

    dms = dms.strip()

    # Match degrees, optional minutes, optional seconds, direction
    pattern = r"""
        (?P<deg>\d+(?:\.\d+)?)°\s*
        (?:(?P<min>\d+(?:\.\d+)?)['′]\s*)?
        (?:(?P<sec>\d+(?:\.\d+)?)["″]\s*)?
        (?P<dir>[NSEW])
    """

    match = re.search(pattern, dms, re.VERBOSE)
    if not match:
        return None

    deg = float(match.group("deg"))
    minutes = float(match.group("min")) if match.group("min") else 0.0
    seconds = float(match.group("sec")) if match.group("sec") else 0.0
    direction = match.group("dir")

    decimal = deg + minutes / 60 + seconds / 3600

    if direction in ["S", "W"]:
        decimal *= -1

    return decimal

# %% [markdown]
# We just need to apply our function to the coordinates and the problem is solved.

# %%
data["Latitude"] = data["Latitude"].apply(dms_to_decimal)
data["Longitude"] = data["Longitude"].apply(dms_to_decimal)

# %% [markdown]
# We need to check if there is any city that does not have coordinates and fortunately everything worked perfectly fine.

# %%
failed = data[data['Latitude'].isna() | data['Longitude'].isna()]
failed[['City','Country']]
# Out:
# Empty DataFrame
# Columns: [City, Country]
# Index: []

# %% [markdown]
# Now that we got all the coordinates, we need export a CSV File of our dataset with the coordinates of each city.

# %%
data.to_csv("city_data_with_coordinates.csv", index=False)
data.head()
# Out:
#        City  Country  Population Density  Population  Working Age Population  \
# 1  Salzburg  Austria               243.0      375489                250472.0
# 2    Vienna  Austria               310.0     2983513               2018818.0
# 3   Antwerp  Belgium               928.0     1139663                723396.0
# 4    Bruges  Belgium               840.0      119765                 74600.0
# 5  Brussels  Belgium               681.0     3284548               2137425.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 1                   20.30                3.0         66689.0
# 2                   20.10               10.2         55770.0
# 3                   27.70                6.2         57595.0
# 4                   25.63                5.6         63083.0
# 5                   27.50               10.7         62500.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 1                                0                             German
# 2                                3  German, English, Turkish, Serbian
# 3                                3              Dutch, French, Arabic
# 4                                0                      Dutch, French
# 5                                3     French, Dutch, Arabic, English
#
#    Average Monthly Salary  Average Rent Price  Average Cost of Living  \
# 1                    3200                1100                    2186
# 2                    2500                1050                    2061
# 3                    2609                 900                    1953
# 4                    2700                1250                    1708
# 5                    3350                1200                    1900
#
#   Last Data Update  Difference  Salary_to_Cost_Ratio   Latitude  Longitude
# 1       2023-11-03        1014              1.463861  47.800000  13.045000
# 2       2024-06-15         439              1.213003  48.208333  16.372500
# 3       2024-08-09         656              1.335893  51.217778   4.400278
# 4       2023-10-25         992              1.580796  51.208889   3.224167
# 5       2023-04-22        1450              1.763158  50.846667   4.352500

# %% [markdown]
# The web scrapping part is concluded.

# %% [markdown]
# ### Interactive Map

# %% [markdown]
# The only thing now missing is the map. As requested the map has to be interactive and it must provide information about each city. The required information to show are the following variables: 'Population', 'Average Monthly Salary' and 'Average Cost of Living'.

# %%
# --- Europe bounding box (strict limits) ---
south_west = [34.0, -25.0]  
north_east = [72.0, 45.0]    

# --- Create the map locked to Europe ---
m = folium.Map(
    location=[54.5260, 15.2551],   # center of Europe
    zoom_start=4,
    min_zoom=4,                    # user cannot zoom out too far
    max_zoom=12,
    max_bounds=True                # lock map to bounding box
)

# --- Apply the bounding box ---
m.fit_bounds([south_west, north_east])
m.options['maxBounds'] = [south_west, north_east]
m.options['maxBoundsViscosity'] = 1.0   # prevents sliding outside boundaries

# --- Add markers for each city ---
for idx, row in data.iterrows():
    lat = row['Latitude']
    lon = row['Longitude']

    # Skip if missing coordinates
    if pd.isna(lat) or pd.isna(lon):
        continue

    city = row['City']
    country = row['Country']

    popup_text = f"""
    <b>{city}, {country}</b><br>
    Population: {row['Population']}<br>
    Avg Monthly Salary: {row['Average Monthly Salary']} €<br>
    Avg Cost of Living: {row['Average Cost of Living']} €
    """

    folium.Marker(
        location=[lat, lon],
        tooltip=city,
        popup=folium.Popup(popup_text, max_width=300)
    ).add_to(m)

# --- Display map ---
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35850814d4e914ee99d92c840efaf1f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35850814d4e914ee99d92c840efaf1f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35850814d4e914ee99d92c840efaf1f6 = L.map(
#                 &quot;map_35850814d4e914ee99d92c840efaf1f6&quot;,
#                 {
#                     center: [54.526, 15.2551],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: [
# [
# -90,
# -180,
# ],
# [
# 90,
# 180,
# ],
# ],
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;maxBounds&quot;: [
# [
# 34.0,
# -25.0,
# ],
# [
# 72.0,
# 45.0,
# ],
# ],
#   &quot;maxBoundsViscosity&quot;: 1.0,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4993fcf870fb6537df0f8a6932c8bea0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 4,
#   &quot;maxZoom&quot;: 12,
#   &quot;maxNativeZoom&quot;: 12,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4993fcf870fb6537df0f8a6932c8bea0.addTo(map_35850814d4e914ee99d92c840efaf1f6);
#
#
#             map_35850814d4e914ee99d92c840efaf1f6.fitBounds(
#                 [[34.0, -25.0], [72.0, 45.0]],
#                 {}
#             );
#
#
#             var marker_49e3b2d45877f5a59668d17ea533aa87 = L.marker(
#                 [47.8, 13.045],
#                 {
# }
#             ).addTo(map_35850814d4e914ee99d92c840efaf1f6);
#
#
#         var popup_2c12be4259345a60b341ef4c3539e9fa = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_3761b55d1a130e0bbe6dc42e4c4d034d = $(`&lt;div id=&quot;html_3761b55d1a130e0bbe6dc42e4c4d034d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Salzburg, Austria&lt;/b&gt;&lt;br&gt;     Population: 375489&lt;br&gt;     Avg Monthly Salary: 3200 €&lt;br&gt;     Avg Cost of Living: 2186 €     &lt;/div&gt;`)[0];
#                 popup_2c12be4259345a60b341ef4c3539e9fa.setContent(html_3761b55d1a130e0bbe6dc42e4c4d034d);
#
#
#
#         marker_49e3b2d45877f5a59668d17ea533aa87.bindPopup(popup_2c12be4259345a60b341ef4c3539e9fa)
#         ;
#
#
#
#
#             marker_49e3b2d45877f5a59668d17ea533aa87.bindTooltip(
#                 `&lt;div&gt;
#                      Salzburg
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5bd1c88a45f56171592bb44fc0973874 = L.marker(
#                 [48.208333333333336, 16.3725],
#                 {
# }
#             ).addTo(map_35850814d4e914ee99d92c840efaf1f6);
#
#
#         var popup_32480d886d24410df58941e75b8a4465 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d91aa96d4a519217b38be66ae5282cf4 = $(`&lt;div id=&quot;html_d91aa96d4a519217b38be66ae5282cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Vienna, Austria&lt;/b&gt;&lt;br&gt;     Population: 2983513&lt;br&gt;     Avg Monthly Salary: 2500 €&lt;br&gt;     Avg Cost of Living: 2061 €     &lt;/div&gt;`)[0];
#                 popup_32480d886d24410df58941e75b8a4465.setContent(html_d91aa96d4a519217b38be66ae5282cf4);
#
#
#
#         marker_5bd1c88a45f56171592bb44fc0973874.bindPopup(popup_32480d886d24410df58941e75b8a4465)
#         ;
#
#
#
#
#             marker_5bd1c88a45f56171592bb44fc0973874.bindTooltip(
#                 `&lt;div&gt;
#                      Vienna
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_cf71b3ff1b7e1731365b4f67d314c835 = L.marker(
#                 [51.217777777777776, 4.400277777777778],
#                 {
# }
#             ).addTo(map_35850814d4e914ee99d92c840efaf1f6);
#
#
#         var popup_abc4cbe227020450cbb88db0e557da29 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_81d54c1906f3e44d45fe9cb8b8b8a27e = $(`&lt;div id=&quot;html_81d54c1906f3e44d45fe9cb8b8b8a27e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Antwerp, Belgium&lt;/b&gt;&lt;br&gt;     Population: 1139663&lt;br&gt;     Avg Monthly Salary: 2609 €&lt;br&gt;     Avg Cost of Living: 1953 €     &lt;/div&gt;`)[0];
#                 popup_abc4cbe227020450cbb88db0e557da29.setContent(html_81d54c1906f3e44d45fe9cb8b8b8a27e);
#
#
#
#         marker_cf71b3ff1b7e1731365b4f67d314c835.bindPopup(popup_abc4cbe227020450cbb88db0e557da29)
#         ;
#
#
#
#
#             marker_cf71b3ff1b7e1731365b4f67d314c835.bindTooltip(
#                 `&lt;div&gt;
#                      Antwerp
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_471c152762b1aadbda12fd2890aac432

# %% [markdown]
# We saved the map as an HTML file.

# %%
m.save("europe_city_map.html")

# %% [markdown]
# ## Data Science In Action

# %% [markdown]
# For the **Data Science in Action**, we chose to create a *Recommendation System* and a *Comparative Analysis*.

# %% [markdown]
# ### Recommendation System

# %% [markdown]
# Our **Recommendation System** is very simple. The user inputs the minimum salary that wants to earn and the maximum cost that wants to spend per month. After, the user inputs the maximum unemployment rate that we requires for the specificc city to make sure that he is able to find a job there. Next, the user inputs the maximum number of extreme heat days that he wants to feel and, to conclude, inputs the number of cities that he wants to see.

# %%
def recommend_cities(
    min_salary=2000,
    max_cost=1600,
    max_unemployment=8.0,
    max_heat_days=30,
    top_n=5
): # giving default values in case the user doesn't give any
   
    # work on a copy to avoid modifying original data
    rec = data.copy()

    # drop rows with missing values in the relevant columns
    # not really necessary because the dataset doesn't have missing values, just in case of changes in the dataset
    rec = rec.dropna(
        subset=[
            "Average Monthly Salary",
            "Average Cost of Living",
            "Unemployment Rate",
            "Days of very strong heat stress",
        ]
    )

    # apply user filters
    mask = (
        (rec["Average Monthly Salary"] >= min_salary)
        & (rec["Average Cost of Living"] <= max_cost)
        & (rec["Unemployment Rate"] <= max_unemployment)
        & (rec["Days of very strong heat stress"] <= max_heat_days)
    )

    rec = rec[mask]

    if rec.empty:
        print("No city matches the selected criteria.\n"
        "Try relaxing one or more constrains.")
        return rec

    # ordering the results from best to worst using these criterias: high salary, low cost, low unemployment
    rec = rec.sort_values(
        by=["Average Monthly Salary", "Average Cost of Living", "Unemployment Rate"],
        ascending=[False, True, True],
    )

    # select columns to display
    columns_to_show = [
        "City",
        "Country",
        "Average Monthly Salary",
        "Average Cost of Living",
        "Unemployment Rate",
        "Days of very strong heat stress",
        "Population",
    ]


    # only keep columns that actually exist
    # again, only needed if the dataset is changed
    columns_to_show = [c for c in columns_to_show if c in rec.columns]

    return rec[columns_to_show].head(top_n)

# %%
def get_numeric_input(prompt, cast_type=float):
    # making sure we get correct values for each variable
    while True:
        try:
            return cast_type(input(prompt))
        except ValueError:
            print("Invalid input. Please enter a number.")

user_expected_sal = get_numeric_input("Minimum monthly salary (€): ", int)
user_maximum_cost = get_numeric_input("Maximum cost of living (€): ", int)
user_unemployment_rate = get_numeric_input("Maximum unemployment rate (%): ", float)
user_heat_days = get_numeric_input("Maximum number of heat stress days per year: ", int)
user_n_cities = get_numeric_input("Number of cities to display: ", int)
# Out:
# Minimum monthly salary (€):  2000
# Maximum cost of living (€):  2000
# Maximum unemployment rate (%):  9
# Maximum number of heat stress days per year:  30
# Number of cities to display:
# Invalid input. Please enter a number.
# Number of cities to display:  5

# %% [markdown]
# This is the print for the **Recommendation System**.

# %%
print('='*42)
print("Results considering user inputed criteria")
print('='*42)
recommend_cities(
    min_salary=user_expected_sal,
    max_cost=user_maximum_cost,
    max_unemployment=user_unemployment_rate,
    max_heat_days=user_heat_days,
    top_n=user_n_cities
)
# Out:
# ==========================================
# Results considering user inputed criteria
# ==========================================
#          City      Country  Average Monthly Salary  Average Cost of Living  \
# 19    Tampere      Finland                    3500                    1600
# 56  Stavanger       Norway                    3500                    2000
# 52  The Hague  Netherlands                    3500                    2000
# 53    Utrecht  Netherlands                    3200                    2000
# 24    Cologne      Germany                    3200                    2000
#
#     Unemployment Rate  Days of very strong heat stress  Population
# 19                6.6                                0      444370
# 56                1.6                                0      339690
# 52                4.2                                1     1103137
# 53                3.0                                3      898712
# 24                3.9                                3     2002550

# %% [markdown]
# ### Comparative Analysis

# %% [markdown]
# In the **Comparative Analysis** part, we explored relationships between variables, made regional comparisons of salary-to-cost and financial-balance-to-cost.

# %%
# Select only numerical columns
numerical_cols = [
    "Population Density",
    "Population",
    "Working Age Population",
    "Youth Dependency Ratio",
    "Unemployment Rate",
    "GDP per Capita",
    "Days of very strong heat stress",
    "Average Monthly Salary",
    "Average Cost of Living"
]

corr_data = data[numerical_cols].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_data, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Socioeconomic Variables")
plt.show()

# %% [markdown]
# To explore relationships among all numerical variables in the dataset, an initial correlation heatmap was generated. Due to the large number of variables, the resulting heatmap, while informative, makes it difficult to isolate specific economic trade-offs relevant to the research question. To focus the analysis on economically meaningful relationships, a second heatmap was created using key indicators related to income, cost of living, labor market conditions, and economic output.

# %%
corr_cols = [
    "Average Monthly Salary",
    "Average Cost of Living",
    "Unemployment Rate",
    "GDP per Capita"
]

corr = data[corr_cols].corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)
plt.title("Correlation Between Key Economic Indicators")
plt.tight_layout()
plt.show()

# %% [markdown]
# The correlation heatmap reveals a strong positive relationship between average monthly salary and cost of living, indicating a clear trade-off between income and affordability. GDP per capita is positively correlated with salary and negatively correlated with unemployment, suggesting that economically stronger cities tend to offer higher wages and better labor market conditions.

# %% [markdown]
# Countries were grouped into Northern, Southern, and Central Europe based on commonly used geographic and economic classifications to enable regional-level comparison.

# %%
# Add country column if not yet created
if "Country" not in data.columns:
    data["Country"] = data["City"].str.split(",").str[1].str.strip()

northern_countries = ["Sweden", "Norway", "Finland", "Denmark", "Netherlands",
                      "Belgium", "Germany", "Ireland", "UK", "Estonia", "Latvia", "Lithuania"]

southern_countries = ["Portugal", "Spain", "Italy", "Greece", "Cyprus", "Malta", "Turkiye"]

def classify_region(country):
    if country in northern_countries:
        return "North"
    elif country in southern_countries:
        return "South"
    else:
        return "Central"

data["Region"] = data["Country"].apply(classify_region)

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(
    data=data,
    x="Average Cost of Living",
    y="Average Monthly Salary",
    hue="Region",
    alpha=0.7
)

plt.plot(
    [data["Average Cost of Living"].min(), data["Average Cost of Living"].max()],
    [data["Average Cost of Living"].min(), data["Average Cost of Living"].max()],
    linestyle="--",
    color="black"
)

plt.xlabel("Average Cost of Living (€)")
plt.ylabel("Average Monthly Salary (€)")
plt.title("Salary vs Cost of Living by European Region")
plt.tight_layout()
plt.show()

# %% [markdown]
# Northern European cities generally occupy the upper-right quadrant of the plot, indicating higher salaries paired with higher living costs. Southern European cities tend to cluster in the lower-left region, reflecting lower salaries but also lower costs. Central European cities show greater dispersion, suggesting a wider range of affordability outcomes. This highlights a regional trade-off between income potential and living expenses across Europe.

# %%
data["Net_Balance"] = (data["Average Monthly Salary"] - data["Average Cost of Living"])

plt.figure(figsize=(10, 7))
sns.scatterplot(
    data=data,
    x="Average Cost of Living",
    y="Net_Balance",
    hue="Region",
    alpha=0.7
)

plt.axhline(0, linestyle="--", color="black")
plt.xlabel("Average Cost of Living (€)")
plt.ylabel("Net Monthly Balance (€)")
plt.title("Net Financial Balance vs Cost of Living")
plt.tight_layout()
plt.show()

# %% [markdown]
# The net financial balance highlights whether higher salaries effectively compensate for higher living costs. While some high-cost cities offer correspondingly high salaries, several cities with moderate living costs achieve higher net balances, indicating better overall affordability. This demonstrates that higher income does not necessarily translate into greater financial advantage.
